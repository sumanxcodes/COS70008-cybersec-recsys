# %%
# Importing necesssary libraries
import pandas as pd
import re

# Read the dataset
df_orgs = pd.read_csv("orgs_full.csv")
df_exs  = pd.read_csv("exercises_full.csv")

# Info and data types of the datasets & columns
df_orgs.info(), df_exs.info(), df_ttps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ORGID                40 non-null     int64
#  1   Industry             40 non-null     object
#  2   Region               40 non-null     object
#  3   Size                 40 non-null     object
#  4   SecurityBudget       40 non-null     object
#  5   PrimarySecurityTeam  40 non-null     object
#  6   Maturity             40 non-null     int64
#  7   Complexity           40 non-null     int64
#  8   ExerciseFrequency    40 non-null     int64
#  9   Threats              40 non-null     object
#  10  TTPs                 40 non-null     object
#  11  Aims                 40 non-null     object
# dtypes: int64(4), object(8)
# memory usage: 3.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EXID               30 non-null     int64
#  1   ExCreation         30 non-null     object
#  2   ExThreat           30 non-null     object
#  3   ExTTPs             30 non-null     object
#  4   ExCategories       30 non-null     object
#  5   ExGroups           30 non-null     object
#  6   ExSoftware         30 non-null     object
#  7   ExStructure        30 non-null     object
#  8   ExMaturity         30 non-null     int64
#  9   ExComplexity       30 non-null     int64
#  10  ExLength           30 non-null     int64
#  11  ExAudience         30 non-null     object
#  12  ExTradeCraftIntra  30 non-null     float64
#  13  ExTradeCraftInter  30 non-null     float64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 3.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    780 non-null    object
#  1    Id     780 non-null    object
# dtypes: object(2)
# memory usage: 12.3+ KB
# (None, None, None)

# %%
# Lambda: normalize one column name
norm_col = lambda c: str(c).strip().lower().replace(" ", "_")
def normalize_columns(df: pd.DataFrame) -> pd.DataFrame:
    return df.rename(columns=norm_col)

# Lets clean the text specially multivalued separated by ;
# splits → trims → removes blanks → sorts → rejoins
def normalize_list_col(s: pd.Series):
    return (s.fillna('')
             .str.split(';')
             .apply(lambda xs: ';'.join(sorted(x.strip() for x in xs if x.strip()))))

# Lets fix the case of the categorical variables
# Convert text to lower case.
def normalise_case(s: pd.Series):
    return (s.astype(str)
         .str.strip()
         .str.replace(r'\s+', ' ', regex=True)
         .str.lower())

# %%
# first of all lets normalise the columna names and make it consistent among all dataset.. best practices..
df_orgs = normalize_columns(df_orgs)
df_exs = normalize_columns(df_exs)


df_orgs.columns.values, df_exs.columns.values, df_ttps.columns.values
# Out:
# (array(['orgid', 'industry', 'region', 'size', 'securitybudget',
#         'primarysecurityteam', 'maturity', 'complexity',
#         'exercisefrequency', 'threats', 'ttps', 'aims'], dtype=object),
#  array(['exid', 'excreation', 'exthreat', 'exttps', 'excategories',
#         'exgroups', 'exsoftware', 'exstructure', 'exmaturity',
#         'excomplexity', 'exlength', 'exaudience', 'extradecraftintra',
#         'extradecraftinter'], dtype=object),
#  array(['Name', ' Id'], dtype=object))

# %%
# ---------- helpers fucntion to clean dataset ----------

def norm_col(c: str) -> str:
    return str(c).strip().lower().replace(" ", "_")

def normalize_columns(df: pd.DataFrame) -> pd.DataFrame:
    return df.rename(columns=norm_col)

def split_semicolons(val):
    if pd.isna(val) or not str(val).strip():
        return []
    return [p.strip() for p in str(val).split(";") if p.strip()]

def norm_token(s: str) -> str:
    s = str(s).strip().lower()
    s = " ".join(s.split())
    return s.replace(" ", "_")

def bucket_numeric(v, bins, labels):
    if pd.isna(v):
        return "unknown"
    idx = np.digitize([float(v)], bins=bins, right=True)[0]
    idx = min(idx, len(labels)-1)
    return labels[idx]

# %%
# Lets concentrate on the exercise dataset only for now..

# Expected exercise feature/columns.. after normalisation
EXPECTED_EX = [
    "exid","exthreat","exttps","excategories","exgroups","exsoftware",
    "exstructure","exaudience","exmaturity","excomplexity","exlength",
    "extradecraftintra","extradecraftinter"
]
missing = [c for c in EXPECTED_EX if c not in df_exs.columns]
if missing: print("misssing exercise cols:", missing)

def tokens_for_exercise(row):
    toks = []
    # Multi-valued categorical → prefixed tokens
    for field, prefix in [
        ("exthreat",    "threat_"),
        ("exttps",      "ttp_"),
        ("excategories","cat_"),
        ("exgroups",    "group_"),
        ("exsoftware",  "soft_"),
        ("exstructure", "struct_"),
        ("exaudience",  "aud_"),
    ]:
        for val in split_semicolons(row.get(field, "")):
            toks.append(prefix + norm_token(val))

    # Numeric → buckets → tokens
    mat = bucket_numeric(row.get("exmaturity", np.nan),   bins=[2,3,5],   labels=["L","M","H"])
    cpx = bucket_numeric(row.get("excomplexity", np.nan), bins=[2,3,5],   labels=["L","M","H"])
    dur = bucket_numeric(row.get("exlength", np.nan),     bins=[60,120,1e9], labels=["short","medium","long"])
    toks += [f"maturity_{mat}", f"complexity_{cpx}", f"len_{dur}"]

    # Tradecraft scores (0..1) → coarse buckets
    for field, prefix in [("extradecraftintra","td_intra_"), ("extradecraftinter","td_inter_")]:
        v = row.get(field, np.nan)
        if pd.isna(v): bucket = "unknown"
        elif float(v) <= 1/3: bucket = "L"
        elif float(v) <= 2/3: bucket = "M"
        else: bucket = "H"
        toks.append(prefix + bucket)

    return " ".join(sorted(set(toks)))

ex_docs = (
    df_exs.assign(doc=lambda d: d.apply(tokens_for_exercise, axis=1))
       [["exid","doc"]]
       .dropna(subset=["exid"])
       .astype({"exid": int})
       .set_index("exid")["doc"]
)

print("Built exercise docs:", ex_docs.shape)
pd.set_option("display.max_colwidth", None)
print(ex_docs.head(1).to_string())
# Out:
# Built exercise docs: (30,)
# exid
# 1    aud_network aud_secops cat_dark_web cat_malware complexity_L group_blackmatter group_conti group_darkside group_fin6 group_lockbit group_revil group_ta505 group_unc1878 group_wizard_spider len_short maturity_H soft_trickbot struct_developments struct_exfiltration struct_impact struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_L threat_ransomware ttp_access_token_manipulation ttp_credential_dumping ttp_defense_evasion ttp_process_injection

# %%
# lets chceck the document we created... 
ex_docs.values
# Out:
# array(['aud_network aud_secops cat_dark_web cat_malware complexity_L group_blackmatter group_conti group_darkside group_fin6 group_lockbit group_revil group_ta505 group_unc1878 group_wizard_spider len_short maturity_H soft_trickbot struct_developments struct_exfiltration struct_impact struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_L threat_ransomware ttp_access_token_manipulation ttp_credential_dumping ttp_defense_evasion ttp_process_injection',
#        'aud_media aud_secops cat_data_breach cat_financial complexity_H group_carbanak group_dridex_group group_evil_corp group_ursnif_operators len_medium maturity_H soft_dridex soft_trickbot struct_detection struct_developments struct_exfiltration struct_impact struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_H threat_banking_trojan ttp_malicious_file ttp_persistence ttp_valid_accounts',
#        'aud_media aud_secops cat_crypto cat_impact complexity_H group_blackmatter group_conti group_darkside group_fin6 group_lockbit group_revil group_ta505 group_unc1878 group_wizard_spider len_short maturity_L soft_maze soft_trickbot struct_detection struct_developments struct_exfiltration struct_impact struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_L threat_ransomware ttp_file_and_directory_discovery ttp_password_spraying ttp_registry_run_keys',
#        'aud_network aud_secops cat_apt cat_c2 cat_supply_chain complexity_M group_8220_gang group_apt3 group_apt33 group_apt41 group_blue_mockingbird group_fin7 group_kinsing group_panda group_rocke group_teamtnt group_turla len_long maturity_H soft_coinminer soft_kinsing soft_nanocore soft_plugx soft_quasarrat soft_xmrig struct_developments struct_exfiltration struct_legal struct_media struct_notification struct_response td_inter_H td_intra_M threat_crypto_miner threat_remote_access_trojan ttp_command_and_scripting_interpreter ttp_credential_access ttp_drive-by_compromise ttp_execution ttp_malicious_file ttp_rootkit ttp_windows_management_instrumentation',
#        'aud_media aud_secops cat_botnet cat_crypto complexity_H group_apt1 group_apt10 group_apt29 group_carbanak group_charming_kitten group_cobalt_group group_fin4 len_long maturity_L soft_bloodhound soft_empire soft_mimikatz struct_detection struct_developments struct_exfiltration struct_impact struct_legal struct_media struct_privacy struct_response struct_validation td_inter_H td_intra_L threat_data_breach ttp_brute_force ttp_execution ttp_process_injection',
#        'aud_exec aud_network cat_crypto cat_dark_web cat_ddos cat_exfiltration complexity_H group_8220_gang group_anonymous group_apt28 group_armada_collective group_blue_mockingbird group_fancy_bear group_killnet group_kinsing group_lizard_squad group_panda group_rocke group_teamtnt len_long maturity_H soft_coinminer soft_groove soft_kinsing soft_loic soft_teamtnt_scripts struct_developments struct_exfiltration struct_legal struct_media struct_notification struct_response struct_validation td_inter_H td_intra_H threat_crypto_miner threat_ddos ttp_discovery ttp_drive-by_compromise ttp_service_stop ttp_valid_accounts',
#        'aud_exec aud_network cat_apt cat_ddos cat_exfiltration cat_web complexity_H group_apt1 group_apt10 group_apt29 group_blackmatter group_carbanak group_charming_kitten group_cobalt_group group_conti group_darkside group_fin4 group_fin6 group_lockbit group_revil group_ta505 group_unc1878 group_wizard_spider len_long maturity_H soft_bloodhound soft_empire soft_revil struct_developments struct_impact struct_legal struct_media struct_privacy struct_response struct_validation td_inter_H td_intra_M threat_data_breach threat_ransomware ttp_account_discovery ttp_exfiltration ttp_impact ttp_remote_file_copy ttp_service_stop ttp_user_execution',
#        'aud_network aud_secops cat_apt cat_data_breach complexity_H group_blackmatter group_conti group_darkside group_fin6 group_lockbit group_revil group_ta505 group_unc1878 group_wizard_spider len_medium maturity_L soft_lockbit soft_trickbot struct_developments struct_exfiltration struct_response td_inter_H td_intra_H threat_ransomware ttp_application_layer_protocol ttp_system_information_discovery ttp_user_execution',
#        'aud_media aud_secops cat_botnet cat_exfiltration cat_supply_chain complexity_M group_blackmatter group_conti group_darkside group_fin6 group_lockbit group_revil group_ta505 group_unc1878 group_wizard_spider len_long maturity_L soft_ryuk struct_impact struct_media struct_response struct_validation td_inter_H td_intra_M threat_ransomware ttp_application_layer_protocol ttp_signed_binary_proxy_execution',
#        'aud_legal aud_secops cat_botnet cat_financial cat_ransom_negotiation cat_web complexity_H group_apt34 group_apt39 group_chopper_operators len_medium maturity_L soft_konni struct_detection struct_developments struct_exfiltration struct_impact struct_legal struct_media struct_privacy struct_response struct_validation td_inter_H td_intra_M threat_web_shell ttp_credential_access ttp_discovery ttp_privilege_escalation ttp_system_information_discovery',
#        'aud_exec aud_media cat_crypto cat_financial complexity_H group_anonymous group_apt28 group_armada_collective group_chelsea_manning group_edward_snowden group_fancy_bear group_killnet group_lizard_squad group_unknown_insider len_medium maturity_M soft_mimikatz soft_mirai soft_psexec struct_developments struct_exfiltration struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_H threat_ddos threat_insider_threat ttp_command_and_scripting_interpreter ttp_discovery ttp_exfiltration ttp_network_service_scanning ttp_trusted_relationship ttp_valid_accounts',
#        'aud_legal aud_secops cat_botnet cat_exfiltration cat_ransom_negotiation cat_web complexity_H group_carbanak group_dridex_group group_evil_corp group_ursnif_operators len_long maturity_H soft_emotet struct_detection struct_developments struct_exfiltration struct_legal struct_media struct_notification struct_privacy struct_validation td_inter_H td_intra_L threat_banking_trojan ttp_data_staged ttp_phishing',
#        'aud_media aud_network cat_botnet cat_data_breach cat_malware cat_supply_chain complexity_M group_apt1 group_apt10 group_apt29 group_carbanak group_charming_kitten group_chelsea_manning group_cobalt_group group_edward_snowden group_fin4 group_unknown_insider len_long maturity_L soft_lazagne soft_mimikatz soft_powershell soft_rubeus soft_sharphound struct_notification struct_response struct_validation td_inter_M td_intra_H threat_data_breach threat_insider_threat ttp_exfiltration ttp_os_credential_dumping ttp_scheduled_task/job ttp_signed_binary_proxy_execution ttp_unsecured_credentials',
#        'aud_exec aud_media cat_dark_web cat_exfiltration cat_financial complexity_H group_anonymous group_apt28 group_apt32 group_armada_collective group_cobalt_group group_evilnum group_fancy_bear group_fin7 group_killnet group_lazarus_group group_lizard_squad group_molerats group_silent_libra len_short maturity_L soft_groove soft_phishme struct_legal struct_notification struct_privacy td_inter_H td_intra_H threat_ddos threat_phishing ttp_defense_evasion ttp_impact ttp_initial_access ttp_network_service_scanning ttp_obfuscated_files_or_information ttp_phishing ttp_signed_binary_proxy_execution',
#        'aud_network aud_secops cat_impact cat_ransom_negotiation cat_web complexity_H group_apt41 group_equation_group group_shadowpad group_unc2452 len_short maturity_H soft_ccleaner soft_sunburst struct_impact struct_privacy struct_validation td_inter_H td_intra_L threat_supply_chain ttp_exfiltration ttp_phishing ttp_user_execution',
#        'aud_legal aud_threat_intel cat_crypto cat_exfiltration cat_financial complexity_H group_apt1 group_apt10 group_apt29 group_carbanak group_charming_kitten group_cobalt_group group_dridex_group group_evil_corp group_fin4 group_ursnif_operators len_medium maturity_H soft_emotet soft_lazagne soft_ursnif soft_zeus struct_impact struct_legal struct_notification struct_response td_inter_H td_intra_H threat_banking_trojan threat_data_breach ttp_discovery ttp_execution ttp_initial_access ttp_obfuscated_files_or_information ttp_persistence ttp_unsecured_credentials ttp_valid_accounts',
#        'aud_network aud_secops cat_botnet cat_exfiltration cat_initial_access cat_ransom_negotiation complexity_M group_8220_gang group_anonymous group_apt28 group_armada_collective group_blue_mockingbird group_fancy_bear group_killnet group_kinsing group_lizard_squad group_panda group_rocke group_teamtnt len_long maturity_H soft_hoic soft_minergate soft_mirai soft_mēris soft_teamtnt_scripts soft_xmrig struct_detection struct_developments struct_impact struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_M threat_crypto_miner threat_ddos ttp_command_and_control ttp_defense_evasion ttp_execution ttp_persistence ttp_scheduled_task/job',
#        'aud_network aud_secops cat_crypto cat_ddos cat_financial complexity_L group_apt34 group_apt39 group_chopper_operators len_short maturity_L soft_aspxspy soft_china_chopper soft_wso_web_shell struct_detection struct_developments struct_exfiltration struct_media struct_notification struct_validation td_inter_H td_intra_L threat_web_shell ttp_defense_evasion ttp_privilege_escalation ttp_web_shell',
#        'aud_legal aud_network cat_botnet cat_initial_access cat_ransom_negotiation complexity_M group_anonymous group_apt28 group_apt3 group_apt33 group_apt41 group_armada_collective group_fancy_bear group_fin7 group_killnet group_lizard_squad group_turla len_long maturity_H soft_hoic soft_mirai soft_plugx soft_quasarrat struct_exfiltration struct_notification struct_privacy td_inter_H td_intra_H threat_ddos threat_remote_access_trojan ttp_data_staged ttp_drive-by_compromise ttp_impact ttp_lateral_movement ttp_masquerading ttp_valid_accounts',
#        'aud_media aud_secops cat_crypto cat_data_breach cat_financial complexity_L group_apt41 group_chelsea_manning group_edward_snowden group_equation_group group_shadowpad group_unc2452 group_unknown_insider len_medium maturity_H soft_ccleaner soft_keepass soft_mimikatz soft_psexec struct_detection struct_exfiltration struct_privacy struct_validation td_inter_L td_intra_M threat_insider_threat threat_supply_chain ttp_defense_evasion ttp_os_credential_dumping ttp_remote_desktop_protocol ttp_remote_services ttp_trusted_relationship',
#        'aud_exec aud_threat_intel cat_ddos cat_initial_access cat_malware cat_ransom_negotiation complexity_L group_apt34 group_apt39 group_chopper_operators len_short maturity_H soft_aspxspy soft_china_chopper struct_detection struct_developments struct_impact struct_legal struct_notification struct_response struct_validation td_inter_H td_intra_H threat_web_shell ttp_discovery ttp_network_service_scanning ttp_privilege_escalation',
#        'aud_network aud_secops cat_botnet cat_data_breach cat_financial cat_supply_chain complexity_H group_apt1 group_apt10 group_apt29 group_carbanak group_charming_kitten group_cobalt_group group_fin4 len_medium maturity_M soft_bloodhound soft_empire soft_lazagne struct_detection struct_developments struct_exfiltration struct_impact struct_privacy struct_response td_inter_H td_intra_M threat_data_breach ttp_access_token_manipulation ttp_user_execution',
#        'aud_legal aud_secops cat_botnet cat_ransom_negotiation cat_web complexity_H group_carbanak group_dridex_group group_evil_corp group_ursnif_operators len_long maturity_H soft_dridex struct_exfiltration struct_impact struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_M threat_banking_trojan ttp_execution ttp_privilege_escalation',
#        'aud_network aud_secops cat_apt cat_malware complexity_M group_apt3 group_apt32 group_apt33 group_apt41 group_cobalt_group group_evilnum group_fin7 group_lazarus_group group_molerats group_silent_libra group_turla len_medium maturity_M soft_agent_tesla soft_king_phisher soft_njrat soft_plugx struct_developments struct_impact struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_M threat_phishing threat_remote_access_trojan ttp_application_layer_protocol ttp_command_and_scripting_interpreter ttp_impact ttp_internal_spearphishing ttp_masquerading ttp_obfuscated_files_or_information ttp_scripting',
#        'aud_secops aud_threat_intel cat_financial cat_impact complexity_H group_apt34 group_apt39 group_apt41 group_chopper_operators group_equation_group group_shadowpad group_unc2452 len_long maturity_H soft_aspxspy soft_notpetya soft_shadowpad soft_solarwinds struct_impact struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_L threat_supply_chain threat_web_shell ttp_account_manipulation ttp_data_exfiltration_over_web_service ttp_drive-by_compromise ttp_masquerading ttp_obfuscated_files_or_information ttp_persistence ttp_privilege_escalation',
#        'aud_network aud_vulnerability_management cat_crypto cat_initial_access cat_supply_chain cat_web complexity_L group_anonymous group_apt28 group_armada_collective group_carbanak group_dridex_group group_evil_corp group_fancy_bear group_killnet group_lizard_squad group_ursnif_operators len_long maturity_L soft_loic soft_mirai soft_zeus struct_exfiltration struct_impact struct_notification struct_privacy td_inter_H td_intra_H threat_banking_trojan threat_ddos ttp_command_and_scripting_interpreter ttp_defense_evasion ttp_execution ttp_impact ttp_initial_access ttp_registry_run_keys ttp_scheduled_task/job',
#        'aud_media aud_network cat_botnet cat_data_breach cat_initial_access cat_ransom_negotiation complexity_H group_apt3 group_apt33 group_apt41 group_carbanak group_dridex_group group_evil_corp group_fin7 group_turla group_ursnif_operators len_medium maturity_M soft_emotet soft_plugx soft_ursnif struct_detection struct_developments struct_impact struct_legal struct_notification struct_response struct_validation td_inter_H td_intra_M threat_banking_trojan threat_remote_access_trojan ttp_boot_or_logon_autostart_execution ttp_command_and_control ttp_defense_evasion ttp_execution ttp_masquerading ttp_network_service_scanning ttp_persistence ttp_remote_system_discovery',
#        'aud_exec aud_secops cat_apt cat_malware complexity_L group_chelsea_manning group_edward_snowden group_unknown_insider len_medium maturity_L soft_powershell struct_impact struct_legal struct_privacy td_inter_H td_intra_L threat_insider_threat ttp_access_token_manipulation ttp_account_manipulation ttp_password_spraying ttp_signed_binary_proxy_execution',
#        'aud_network aud_secops cat_impact cat_web complexity_H group_apt41 group_equation_group group_shadowpad group_unc2452 len_long maturity_H soft_notpetya soft_sunburst struct_detection struct_developments struct_impact struct_legal struct_media struct_notification struct_privacy struct_response struct_validation td_inter_H td_intra_M threat_supply_chain ttp_exfiltration ttp_malicious_file',
#        'aud_secops aud_threat_intel cat_c2 cat_impact cat_ransom_negotiation cat_web complexity_L group_apt1 group_apt10 group_apt29 group_apt34 group_apt39 group_carbanak group_charming_kitten group_chopper_operators group_cobalt_group group_fin4 len_short maturity_L soft_china_chopper soft_empire soft_konni soft_mimikatz struct_detection struct_developments struct_exfiltration struct_impact struct_legal struct_media struct_notification struct_response struct_validation td_inter_H td_intra_H threat_data_breach threat_web_shell ttp_discovery ttp_masquerading ttp_service_stop ttp_unsecured_credentials ttp_valid_accounts'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# We already space-join tokens; keep case as-is & treat any non-space as a token char.
tfidf = TfidfVectorizer(lowercase=False, token_pattern=r"[^ ]+")
X_ex  = tfidf.fit_transform(ex_docs.values)   # rows align to ex_docs.index order

print("DTM shape (exercises × features):", X_ex.shape)

ex_sim = cosine_similarity(X_ex, X_ex)
ex_sim_df = pd.DataFrame(ex_sim, index=ex_docs.index, columns=ex_docs.index)
print("Similarity matrix shape:", ex_sim_df.shape)
# Out:
# DTM shape (exercises × features): (30, 200)
# Similarity matrix shape: (30, 30)

# %%
ex_sim_df
# Out:
# exid        1         2         3         4         5         6         7   \
# exid
# 1     1.000000  0.201992  0.595990  0.081390  0.203916  0.131158  0.407433
# 2     0.201992  1.000000  0.257887  0.140975  0.241546  0.169245  0.130048
# 3     0.595990  0.257887  1.000000  0.063856  0.256192  0.102120  0.389936
# 4     0.081390  0.140975  0.063856  1.000000  0.103175  0.418797  0.100134
# 5     0.203916  0.241546  0.256192  0.103175  1.000000  0.120261  0.414930
# 6     0.131158  0.169245  0.102120  0.418797  0.120261  1.000000  0.193796
# 7     0.407433  0.130048  0.389936  0.100134  0.414930  0.193796  1.000000
# 8     0.538270  0.241232  0.542230  0.086025  0.099144  0.080041  0.459123
# 9     0.497302  0.111717  0.532632  0.127208  0.174767  0.078874  0.454694
def similar_exercises(target_exid: int, top_n: int = 5) -> pd.DataFrame:
    if target_exid not in ex_sim_df.index:
        raise KeyError(f"exid {target_exid} not found")
    s = ex_sim_df.loc[target_exid].drop(index=target_exid)
    s = s.sort_values(ascending=False).head(top_n).round(4)
    out = s.reset_index()
    out.columns = ["exid","similarity"]
    return out

print(similar_exercises(1, 5))
print(similar_exercises(10, 5))
# Out:
#    exid  similarity
# 0     3      0.5960
# 1     8      0.5383
# 2     9      0.4973
# 3     7      0.4074
# 4    18      0.2377
#    exid  similarity
# 0    30      0.4520
# 1    21      0.4277
# 2    23      0.4268
# 3    18      0.4143
# 4    12      0.3280

# %%
def tokens_for_org(row):
    toks = []
    for field, prefix in [("threats","threat_"), ("ttps","ttp_"), ("aims","aim_")]:
        for val in split_semicolons(row.get(field, "")):
            toks.append(prefix + norm_token(val))
    # Bucket maturity/complexity to match exercise tokens
    mat = bucket_numeric(row.get("maturity", np.nan),   bins=[2,3,5], labels=["L","M","H"])
    cpx = bucket_numeric(row.get("complexity", np.nan), bins=[2,3,5], labels=["L","M","H"])
    toks += [f"maturity_{mat}", f"complexity_{cpx}"]
    # Optional org size
    if "size" in row and isinstance(row["size"], str) and row["size"].strip():
        toks.append("size_" + norm_token(row["size"]))
    return " ".join(sorted(set(toks)))

org_docs = (
    df_orgs.assign(doc=lambda d: d.apply(tokens_for_org, axis=1))
        [["orgid","doc"]]
        .dropna(subset=["orgid"])
        .astype({"orgid": int})
        .set_index("orgid")["doc"]
)

X_org = tfidf.transform(org_docs.values)      # same vocabulary
org_ex_sim = cosine_similarity(X_org, X_ex)
org_ex_sim_df = pd.DataFrame(org_ex_sim, index=org_docs.index, columns=ex_docs.index)

def recommend_for_org(org_id: int, top_n: int = 5) -> pd.DataFrame:
    if org_id not in org_ex_sim_df.index:
        raise KeyError(f"orgid {org_id} not found")
    s = org_ex_sim_df.loc[org_id].sort_values(ascending=False).head(top_n).round(4)
    out = s.reset_index()
    out.columns = ["exid","similarity"]
    return out

# EXAMPLE
print(recommend_for_org(1, 5))
# Out:
#    exid  similarity
# 0    27      0.2214
# 1    14      0.2131
# 2    21      0.1675
# 3    11      0.1348
# 4    19      0.1321

# %%
def reweight_by_prefix(X, vocab: dict, prefix: str, factor: float):
    idxs = [i for tok, i in vocab.items() if tok.startswith(prefix)]
    if not idxs: return X
    X = X.tocsc(copy=True)
    X[:, idxs] = X[:, idxs] * factor
    return X.tocsr()

# Rebuild a weighted similarity using TTP weight = 3.0
vocab = tfidf.vocabulary_
X_ex_w = reweight_by_prefix(X_ex, vocab, "ttp_", 2.0)
ex_sim_w = cosine_similarity(X_ex_w, X_ex_w)
ex_sim_w_df = pd.DataFrame(ex_sim_w, index=ex_docs.index, columns=ex_docs.index)

def most_similar_exercises_weighted(target_exid: int, top_n: int = 5) -> pd.DataFrame:
    if target_exid not in ex_sim_w_df.index:
        raise KeyError(f"exid {target_exid} not found")
    s = ex_sim_w_df.loc[target_exid].drop(index=target_exid)
    s = s.sort_values(ascending=False).head(top_n).round(4)
    out = s.reset_index()
    out.columns = ["exid","similarity"]
    return out

# EXAMPLE
print(most_similar_exercises_weighted(1, 5))
# Out:
